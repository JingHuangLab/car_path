# %%
# Generic Python.
import sys, os
sys.dont_write_bytecode = True
from typing import Type, List

# Misc.
import numpy
import matplotlib.pyplot as plt
import matplotlib.ticker as plt_ticker
from matplotlib.axes import Axes
import seaborn as sns

# %%
finene = numpy.load('./ms0_car/fig_omm/c12pep_c36m/snake_path/snake_path_fin_min_ener.npy')
finene.shape
# Out:
# (521,)

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(7,4), dpi=900)
plt.subplots_adjust(left=1./7., right=6.5/7., top=3.4/4., bottom=1./4.)

ax.plot(   numpy.arange(finene.shape[0]), numpy.asarray(finene), color='#9A1663', marker='.', markersize=5, zorder=5)
# ax.scatter(numpy.arange(finene.shape[0])[::25], numpy.asarray(finene)[::25], s=.1, c='red')

ax.set( xlim=(-10,  530), xticks=numpy.arange(0, 501, 100), 
        ylim=(-205, 5), yticks=numpy.arange(-200, 5, 50))
ax.set_xlabel(r"# Replicas")
ax.set_ylabel(r"Energy ($kcal\ mol^{-1}$)")
ax.tick_params(direction='in', width=1.5, length=4, labelsize=12)
ax.spines['left'].set_linewidth(1.5)
ax.spines['bottom'].set_linewidth(1.5)
ax.spines['top'  ].set_visible(False)
ax.spines['right'].set_visible(False)

plt.savefig(f'./ms0_car/fig_omm/c12pep_c36m/plot_c12pep_ener.jpeg')
